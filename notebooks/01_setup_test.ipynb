# %%
import sys
import torch
import numpy as np
import pandas as pd
import cv2
import skimage
import skfuzzy

print("Python:", sys.version)
print("Python path:", sys.executable)
print("PyTorch:", torch.__version__)
print("MPS GPU:", torch.backends.mps.is_available())
# Out:
# Python: 3.11.15 (main, Jun 11 2026, 15:14:57) [Clang 20.1.8 ]
# Python path: /opt/miniconda3/envs/multiscale-imaging/bin/python
# PyTorch: 2.13.0
# MPS GPU: True
